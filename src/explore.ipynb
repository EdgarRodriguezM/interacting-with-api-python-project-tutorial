# %% [markdown]
# # Explore here

# %%
import os
import pandas as pd
import seaborn as sns
from dotenv import load_dotenv

# load the .env file variables
load_dotenv()

# Get credential values
client_id = os.environ.get("CLIENT_ID")
client_secret = os.environ.get("CLIENT_SECRET")

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

auth_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
spotify = spotipy.Spotify(auth_manager=auth_manager)

# %%
lz_uri = 'spotify:artist:43ZHCT0cAZBISjO8DG9PnE'

spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())
results = spotify.artist_top_tracks(lz_uri)

canciones = []
popularidad = []
duracion = []

for track in results['tracks'][:10]:
    canciones.append(track["name"])
    popularidad.append(track["popularity"])
    duracion.append(track["duration_ms"])

dic = {
    "Canciones": canciones,
    "Popularidad": popularidad,
    "Duracion": duracion
}

df = pd.DataFrame(dic)
df
# Out:
#                                            Canciones  Popularidad  Duracion
# 0                                     Blue Christmas           86    130234
# 1                         Can't Help Falling in Love           82    185877
# 2  Here Comes Santa Claus (Right Down Santa Claus...           80    117592
# 3                                       Burning Love           77    171533
# 4                                   Suspicious Minds           76    263135
# 5                                     Jailhouse Rock           71    146933
# 6                         O Little Town of Bethlehem           74    158979
# 7                                  Always On My Mind           73    219109
# 8                        Santa Claus Is Back In Town           71    145532
# 9  A Little Less Conversation - JXL Radio Edit Remix           69    211506
